# %%
import pandas as pd

# %%
import numpy as np
from sklearn.metrics import r2_score

# %%
from sklearn.linear_model import LinearRegression
import matplotlib.pyplot as plt

regr = LinearRegression()

df = pd.read_csv("houseprice.csv")

# %%
print(df.head())
print(df.describe())
# Out:
#    SizeSqm  Bedrooms  Bathrooms  AgeYears  DistanceKm   Price
# 0       55         1          1        12           8  120000
# 1       75         2          1        10           6  160000
# 2       80         2          2         8           5  180000
# 3      120         3          2         5           4  260000
# 4      150         4          3         3           4  350000
#           SizeSqm   Bedrooms  Bathrooms   AgeYears  DistanceKm          Price
# count   15.000000  15.000000  15.000000  15.000000   15.000000      15.000000
# mean   109.666667   2.866667   2.133333   7.266667    5.466667  245666.666667
# std     38.194365   1.187234   0.915475   4.431489    2.231805   98956.459882
# min     55.000000   1.000000   1.000000   1.000000    2.000000  110000.000000
# 25%     77.500000   2.000000   1.500000   3.500000    4.000000  167500.000000
# 50%    110.000000   3.000000   2.000000   6.000000    5.000000  240000.000000
# ...

# %%
select_price=['SizeSqm', 'Bedrooms', 'AgeYears']
X = df[select_price]
y= df["Price"]

#regr = linear_model.LinearRegression()
regr.fit(X,y)

predictprice = regr.predict([[110, 3, 4]])

price = float(predictprice)

print( (f" ${ price:,.2f}"))
# Out:
#  $255,684.47
# C:\Users\USER\anaconda3\Lib\site-packages\sklearn\utils\validation.py:2749: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# C:\Users\USER\AppData\Local\Temp\ipykernel_15592\4232868099.py:10: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   price = float(predictprice)

# %%
y_pred = regr.predict(X)
r2 = r2_score(y_pred,y)
print(f"R2 Score:{r2:.3f}")
# Out:
# R2 Score:0.991

# %% [markdown]
# # RESULT INTERPRETATION

# %% [markdown]
# My results shows 99% ,the 1% is due to the other factors like the bedrooms and distance

# %% [markdown]
# this shows that the model is good model,it can be use for the realworld application

# %%
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[53], line 2
#       1 actual = np.random.binomial(1,.2, size=100)
# ----> 2 predicted = np.random.bionomial(predictprice)
#       4 acur=metrics.acuuracy_score(actual,predicted)
#       5 print(acur)
#
# AttributeError: module 'numpy.random' has no attribute 'bionomial'
