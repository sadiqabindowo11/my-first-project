# %%
import pandas as pd
import matplotlib.pyplot as plt


melb_file_path = "C:\\Users\\USER\\Downloads\\archive\\melb_data.csv"

melb_data =pd.read_csv(melb_file_path)

plt.hist(melb_file_path, 5)
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt


x = np.random.normal(5.0,1.0,1000)
y = np.random.normal(10.2, 2.0,1000)

plt.scatter(x, y)
plt.show()

# %%
import numpy as np
from sklearn.metrics import r2_score

x = [1,2,3,5,6,7,8,9,10,12,13,14,15,16,18,19,21,22]
y = [100,90,80,60,60,55,60,65,70,70,75,76,78,79,90,99,99,100]

mymodel = numpy.poly1(numpy.polyfit(x,y,3))

print(r2_score(y,mymodel(x)))
# Out:
# ----------------------------------------------------------------
# ModuleNotFoundError            Traceback (most recent call last)
# Cell In[2], line 2
#       1 import numpy as np
# ----> 2 from sklearn.metrics import r2_score
#       4 x = [1,2,3,5,6,7,8,9,10,12,13,14,15,16,18,19,21,22]
#       5 y = [100,90,80,60,60,55,60,65,70,70,75,76,78,79,90,99,99,100]
#
# ModuleNotFoundError: No module named 'sklearn'
