# %%
import numpy as np
from sklearn.metrics import r2_score

# %%
x = [1,2,3,5,6,7,8,9,10,12,13,14,15,16,18,19,21,22]
y = [100,90,80,60,60,65,70,70,55,75,76,75,78,79,90,99,99,100]

mymodel = np.poly1d(np.polyfit(x,y,3))
speed = mymodel(17)
print(speed)
# Out:
# 88.12050344113203

# %%
import pandas as pd
from sklearn import linear_model
from sklearn.preprocessing import StandardScaler
scale = StandardScaler()


df = pd.read_csv('Student_Performance.csv')

X = df[['Hours Studied', 'Sample Question Papers Practiced']]

y = df['Performance Index']

scaledX = scale.fit_transform(X)

regr = linear_model.LinearRegression()
regr.fit(scaledX, y)

scaled = scale.transform([[5,4]])

predictedindex = regr.predict([scaled[0,]])
print(predictedindex)
# Out:
# [55.10081017]
# C:\Users\USER\anaconda3\Lib\site-packages\sklearn\utils\validation.py:2749: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(

# %%
df = pd.read_csv('Student_Performance.csv')
df.head()
# Out:
#    Hours Studied  Previous Scores Extracurricular Activities  Sleep Hours  \
# 0              7               99                        Yes            9
# 1              4               82                         No            4
# 2              8               51                        Yes            7
# 3              5               52                        Yes            5
# 4              7               75                         No            8
#
#    Sample Question Papers Practiced  Performance Index
# 0                                 1               91.0
# 1                                 2               65.0
# 2                                 2               45.0
# 3                                 2               36.0
# 4                                 5               66.0

# %%
X = df[['Hours Studied','Sleep Hours','Sample Question Papers Practiced']]
y = df['Performance Index']

regr = linear_model.LinearRegression()
regr.fit(x,y)

scaledX = scale.fit_transform(X)

print(scaledX)
# Out:
# ----------------------------------------------------------------
# NameError                      Traceback (most recent call last)
# Cell In[25], line 7
#       2 y = df['Performance Index']
#       4 #regr = linear_model.LinearRegression()
#       5 #regr.fit(x,y)
# ----> 7 scaledX = scale.fit_transform(X)
#       9 print(scaledX)
#
# NameError: name 'scale' is not defined

# %%
import pandas as pd
import numpy as np
from sklearn import linear_model

# %%
df = pd.read_csv("house_prices.csv")
print(df)
# Out:
# ----------------------------------------------------------------
# FileNotFoundError              Traceback (most recent call last)
# Cell In[37], line 1
# ----> 1 df = pd.read_csv("house_prices.csv")
#       2 print(df)
#
# File ~\anaconda3\Lib\site-packages\pandas\io\parsers\readers.py:1026, in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, date_format, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options, dtype_backend)
#    1013 kwds_defaults = _refine_defaults_read(
#    1014     dialect,
# ...

# %%
import pandas as pd

iowa_file_path = '../input/home-data-for-ml-course/train.csv'
home_date = pd.read_csv(iowa_file_path)
# Out:
# ----------------------------------------------------------------
# FileNotFoundError              Traceback (most recent call last)
# Cell In[52], line 4
#       1 import pandas as pd
#       3 iowa_file_path = '../input/home-data-for-ml-course/train.csv'
# ----> 4 home_date = pd.read_csv(iowa_file_path)
#
# File ~\anaconda3\Lib\site-packages\pandas\io\parsers\readers.py:1026, in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, date_format, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options, dtype_backend)
# ...

# %%
y =['Performance Index']
stu_perf =['Hours Studied', 'Previous Score','Sample Question Papers Practice']
X =studentperformance[stu_perf]
X.describe()
# Out:
# ----------------------------------------------------------------
# KeyError                       Traceback (most recent call last)
# Cell In[47], line 3
#       1 y =['Performance Index']
#       2 stu_perf =['Hours Studied', 'Previous Score','Sample Question Papers Practice']
# ----> 3 X =studentperformance[stu_perf]
#       4 X.describe()
#
# File ~\anaconda3\Lib\site-packages\pandas\core\frame.py:4119, in DataFrame.__getitem__(self, key)
#    4117     if is_iterator(key):
#    4118         key = list(key)
# -> 4119     indexer = self.columns._get_indexer_strict(key, "columns")[1]
#    4121 # take() does not accept boolean indexers
#    4122 if getattr(indexer, "dtype", None) == bool:
#
# File ~\anaconda3\Lib\site-packages\pandas\core\indexes\base.py:6212, in Index._get_indexer_strict(self, key, axis_name)
#    6209 else:
#    6210     keyarr, indexer, new_indexer = self._reindex_non_unique(keyarr)
# -> 6212 self._raise_if_missing(keyarr, indexer, axis_name)
# ...

# %%
stu_perf.describe()
# Out:
# ----------------------------------------------------------------
# NameError                      Traceback (most recent call last)
# Cell In[46], line 1
# ----> 1 stu_perf.describe()
#
# NameError: name 'stu_perf' is not defined
