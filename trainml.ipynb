# %%
from sklearn.neigbors import KNeigborsClassifier
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 from sklearn.neigbors import KNeigborsClassifier
#
# ModuleNotFoundError: No module named 'sklearn.neigbors'
